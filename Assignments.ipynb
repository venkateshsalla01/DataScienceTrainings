# %% [markdown]
# **Assignment 1**
#
# 1. Write a python program to calculate the area of a rectangle given its length and width
# 2. Calculate the compound interest for a given principal amount, interest rate and time period.
# 3. Given list of integers, find the sum of all positive numbers
# 4. Create a program that takes a year as input and checks if it is a leap year or not
# 5. Create a loop that prints all the prime numbers between 1 and 500

# %% [markdown]
# **Assignment 2**
# 1. Write a Python function that finds all the permutations of the members of a list.
# 2. Write a Python function to check if a list is a palindrome or not. Return true otherwise false.
# 3. Write a Python program to find all the pairs in a list whose sum is equal to a given
#
# Example:
#
# Original list:
#
# [1, 2, 3, 4, 5, 6, 7, 8, 9]
#
# List all pairs of the said list whose sum equals to 10
#
# [(6, 4), (7, 3), (8, 2), (9, 1)]
#
# 4. Write a Python program to check if the list contains three consecutive common numbers
#
# Example:
#
# a = [1, 2, 2, 2, 3, 4, 5]
#
# output: Returns True when it found the consecutive common numbers
#
# 5. Write a Python program to Extract elements with Frequency greater than K
#
# Input : test_list = [4, 6, 4, 3, 3, 4, 3, 4, 3, 8], K = 3
#
# Output : [4, 3]
#
# Explanation : Both elements occur 4 times.
